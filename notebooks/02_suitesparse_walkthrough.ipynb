# %% [markdown]
# # SuiteSparse quick run
# Fetch a few matrices with `ssgetpy` and benchmark IR.

# %%
# %pip install ssgetpy
from benchmarks.run_suitesparse import run_experiment
run_experiment(limit=2, precond='ilu', plot=True)
